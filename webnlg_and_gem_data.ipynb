# %% [markdown]
# <a href="https://colab.research.google.com/github/MuroriM/GEM-table-to-text-through-AMR/blob/main/webnlg_and_gem_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/huggingface/datasets.git
from datasets import load_dataset
# Out:
# ...
#   Cloning https://github.com/huggingface/datasets.git to /tmp/pip-req-build-trasv46d
#   Running command git clone -q https://github.com/huggingface/datasets.git /tmp/pip-req-build-trasv46d
# ...
#   Created wheel for datasets: filename=datasets-1.6.2.dev0-cp37-none-any.whl size=224908 sha256=b1c8d07543ace1306452f69e4ce78a06c8686379c57dd4f42b860195515b0778
#   Stored in directory: /tmp/pip-ephem-wheel-cache-u_yui6zj/wheels/3e/af/ff/d1cdb5d0f9cff6eba2042a16b477ada497e23f1a3b6950b928
# Successfully built datasets

# %%
web_nlg_data = load_dataset("gem", "web_nlg_en")
web_nlg_data
# Out:
# WARNING:datasets.builder:Reusing dataset gem (/root/.cache/huggingface/datasets/gem/web_nlg_en/1.1.0/a94b3f239aacc2081ffa3ea4414c3cddff25bb680c09756a27ec3e76547187b4)
# DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'input', 'target', 'references', 'category', 'webnlg_id'],
#         num_rows: 35426
#     })
#     validation: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'input', 'target', 'references', 'category', 'webnlg_id'],
#         num_rows: 1667
#     })
#     test: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'input', 'target', 'references', 'category', 'webnlg_id'],
#         num_rows: 1779
#     })
#     challenge_train_sample: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'input', 'target', 'references', 'category', 'webnlg_id'],
#         num_rows: 502
#     })
#     challenge_validation_sample: Dataset({
# ...

# %%
web_nlg_data['train'][0]
# Out:
# {'category': 'Airport',
#  'gem_id': 'web_nlg_en-train-0',
#  'gem_parent_id': 'web_nlg_en-train-0',
#  'input': ['Aarhus_Airport | cityServed | "Aarhus, Denmark"'],
#  'references': [],
#  'target': 'The Aarhus is the airport of Aarhus, Denmark.',
#  'webnlg_id': 'train/Airport/1/Id1'}

# %%
dart_data = load_dataset("gem", "dart")
dart_data
# Out:
# WARNING:datasets.builder:Reusing dataset gem (/root/.cache/huggingface/datasets/gem/dart/1.1.0/a94b3f239aacc2081ffa3ea4414c3cddff25bb680c09756a27ec3e76547187b4)
# DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'dart_id', 'tripleset', 'subtree_was_extended', 'target_sources', 'target', 'references'],
#         num_rows: 62659
#     })
#     validation: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'dart_id', 'tripleset', 'subtree_was_extended', 'target_sources', 'target', 'references'],
#         num_rows: 2768
#     })
#     test: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'dart_id', 'tripleset', 'subtree_was_extended', 'target_sources', 'target', 'references'],
#         num_rows: 5097
#     })
# })

# %%
for entry in dart_data['train'][:50]:
  print(entry)
# Out:
# Streaming output truncated to the last 5000 lines.
# {'dart_id': 28369, 'gem_id': 'dart-train-57659', 'gem_parent_id': 'dart-train-57659', 'references': [], 'subtree_was_extended': False, 'target': 'The Waterman is a lowly rated fast food restaurant in Luton suitable for adults -- moderate food bracket.', 'target_sources': ['e2e', 'e2e'], 'tripleset': [['The Waterman', 'eatType', 'restaurant'], ['The Waterman', 'food', 'Fast food'], ['The Waterman', 'customer rating', '1 out of 5']]}
# ...

# %%
type(dart_data)
# Out:
# datasets.dataset_dict.DatasetDict

# %%
dart_data.save_to_disk("/content/dart")
