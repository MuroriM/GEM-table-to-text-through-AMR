# %% [markdown]
# <a href="https://colab.research.google.com/github/MuroriM/GEM-table-to-text-through-AMR/blob/main/all_gem_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/huggingface/datasets.git
from datasets import load_dataset
# Out:
# ...
#   Cloning https://github.com/huggingface/datasets.git to /tmp/pip-req-build-9e_cp5b_
#   Running command git clone -q https://github.com/huggingface/datasets.git /tmp/pip-req-build-9e_cp5b_
# ...
#      |████████████████████████████████| 245kB 5.5MB/s
# ...
#      |████████████████████████████████| 112kB 9.2MB/s
# ...
#   Created wheel for datasets: filename=datasets-1.6.2.dev0-cp37-none-any.whl size=224908 sha256=b8d4040be671959a11f07c67fa9b08fb0b229faa29fe0cd9839fe42a55d3d751
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lo6znmxt/wheels/3e/af/ff/d1cdb5d0f9cff6eba2042a16b477ada497e23f1a3b6950b928
# Successfully built datasets
# ...

# %%
data = load_dataset("gem", "common_gen")
data
# Out:
# ...
# Dataset gem downloaded and prepared to /root/.cache/huggingface/datasets/gem/common_gen/1.1.0/a94b3f239aacc2081ffa3ea4414c3cddff25bb680c09756a27ec3e76547187b4. Subsequent calls will reuse this data.
# DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'concept_set_id', 'concepts', 'target', 'references'],
#         num_rows: 67389
#     })
#     validation: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'concept_set_id', 'concepts', 'target', 'references'],
#         num_rows: 993
#     })
#     test: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'concept_set_id', 'concepts', 'target', 'references'],
#         num_rows: 1497
#     })
#     challenge_train_sample: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'concept_set_id', 'concepts', 'target', 'references'],
#         num_rows: 500
#     })
#     challenge_validation_sample: Dataset({
# ...

# %%
data = load_dataset("gem", "cs_restaurants")
data
# Out:
# ...
# Dataset gem downloaded and prepared to /root/.cache/huggingface/datasets/gem/cs_restaurants/1.1.0/a94b3f239aacc2081ffa3ea4414c3cddff25bb680c09756a27ec3e76547187b4. Subsequent calls will reuse this data.
# DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'dialog_act', 'dialog_act_delexicalized', 'target_delexicalized', 'target', 'references'],
#         num_rows: 3569
#     })
#     validation: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'dialog_act', 'dialog_act_delexicalized', 'target_delexicalized', 'target', 'references'],
#         num_rows: 781
#     })
#     test: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'dialog_act', 'dialog_act_delexicalized', 'target_delexicalized', 'target', 'references'],
#         num_rows: 842
#     })
#     challenge_train_sample: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'dialog_act', 'dialog_act_delexicalized', 'target_delexicalized', 'target', 'references'],
# ...

# %%
data = load_dataset("gem", "web_nlg_en")
data
# Out:
# ...
# Dataset gem downloaded and prepared to /root/.cache/huggingface/datasets/gem/web_nlg_en/1.1.0/a94b3f239aacc2081ffa3ea4414c3cddff25bb680c09756a27ec3e76547187b4. Subsequent calls will reuse this data.
# DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'input', 'target', 'references', 'category', 'webnlg_id'],
#         num_rows: 35426
#     })
#     validation: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'input', 'target', 'references', 'category', 'webnlg_id'],
#         num_rows: 1667
#     })
#     test: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'input', 'target', 'references', 'category', 'webnlg_id'],
#         num_rows: 1779
#     })
#     challenge_train_sample: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'input', 'target', 'references', 'category', 'webnlg_id'],
#         num_rows: 502
#     })
#     challenge_validation_sample: Dataset({
# ...

# %%
data = load_dataset("gem", "web_nlg_ru")
data
# Out:
# ...
# Dataset gem downloaded and prepared to /root/.cache/huggingface/datasets/gem/web_nlg_ru/1.1.0/a94b3f239aacc2081ffa3ea4414c3cddff25bb680c09756a27ec3e76547187b4. Subsequent calls will reuse this data.
# DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'input', 'target', 'references', 'category', 'webnlg_id'],
#         num_rows: 14630
#     })
#     validation: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'input', 'target', 'references', 'category', 'webnlg_id'],
#         num_rows: 790
#     })
#     test: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'input', 'target', 'references', 'category', 'webnlg_id'],
#         num_rows: 1102
#     })
#     challenge_train_sample: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'input', 'target', 'references', 'category', 'webnlg_id'],
#         num_rows: 501
#     })
#     challenge_validation_sample: Dataset({
# ...

# %%
data = load_dataset("gem", "wiki_auto_asset_turk")
data
# Out:
# ...
# Dataset gem downloaded and prepared to /root/.cache/huggingface/datasets/gem/wiki_auto_asset_turk/1.1.0/a94b3f239aacc2081ffa3ea4414c3cddff25bb680c09756a27ec3e76547187b4. Subsequent calls will reuse this data.
# DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'source', 'target', 'references'],
#         num_rows: 483801
#     })
#     validation: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'source', 'target', 'references'],
#         num_rows: 20000
#     })
#     test_asset: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'source', 'target', 'references'],
#         num_rows: 359
#     })
#     test_turk: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'source', 'target', 'references'],
#         num_rows: 359
#     })
#     challenge_train_sample: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'source', 'target', 'references'],
#         num_rows: 500
#     })
# ...

# %%
data = load_dataset("gem", "wiki_lingua_es_en_v0")
data
# Out:
# ...
# Dataset gem downloaded and prepared to /root/.cache/huggingface/datasets/gem/wiki_lingua_es_en_v0/1.1.0/a94b3f239aacc2081ffa3ea4414c3cddff25bb680c09756a27ec3e76547187b4. Subsequent calls will reuse this data.
# DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'source', 'target', 'references'],
#         num_rows: 79515
#     })
#     validation: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'source', 'target', 'references'],
#         num_rows: 8835
#     })
#     test: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'source', 'target', 'references'],
#         num_rows: 19797
#     })
# })

# %%
data = load_dataset("gem", "e2e_nlg")
data
# Out:
# ...
# Dataset gem downloaded and prepared to /root/.cache/huggingface/datasets/gem/e2e_nlg/1.1.0/a94b3f239aacc2081ffa3ea4414c3cddff25bb680c09756a27ec3e76547187b4. Subsequent calls will reuse this data.
# DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'meaning_representation', 'target', 'references'],
#         num_rows: 33525
#     })
#     validation: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'meaning_representation', 'target', 'references'],
#         num_rows: 4299
#     })
#     test: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'meaning_representation', 'target', 'references'],
#         num_rows: 4693
#     })
#     challenge_train_sample: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'meaning_representation', 'target', 'references'],
#         num_rows: 500
#     })
#     challenge_validation_sample: Dataset({
# ...

# %%
data = load_dataset("gem", "mlsum_de")
data
# Out:
# ...
# Dataset gem downloaded and prepared to /root/.cache/huggingface/datasets/gem/mlsum_de/1.1.0/a94b3f239aacc2081ffa3ea4414c3cddff25bb680c09756a27ec3e76547187b4. Subsequent calls will reuse this data.
# DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'text', 'topic', 'url', 'title', 'date', 'target', 'references'],
#         num_rows: 220748
#     })
#     validation: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'text', 'topic', 'url', 'title', 'date', 'target', 'references'],
#         num_rows: 11392
#     })
#     test: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'text', 'topic', 'url', 'title', 'date', 'target', 'references'],
#         num_rows: 10695
#     })
#     challenge_train_sample: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'text', 'topic', 'url', 'title', 'date', 'target', 'references'],
#         num_rows: 500
#     })
#     challenge_validation_sample: Dataset({
# ...

# %%
data = load_dataset("gem", "mlsum_es")
data
# Out:
# ...
# Dataset gem downloaded and prepared to /root/.cache/huggingface/datasets/gem/mlsum_es/1.1.0/a94b3f239aacc2081ffa3ea4414c3cddff25bb680c09756a27ec3e76547187b4. Subsequent calls will reuse this data.
# DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'text', 'topic', 'url', 'title', 'date', 'target', 'references'],
#         num_rows: 259888
#     })
#     validation: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'text', 'topic', 'url', 'title', 'date', 'target', 'references'],
#         num_rows: 9977
#     })
#     test: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'text', 'topic', 'url', 'title', 'date', 'target', 'references'],
#         num_rows: 13366
#     })
#     challenge_train_sample: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'text', 'topic', 'url', 'title', 'date', 'target', 'references'],
#         num_rows: 500
#     })
#     challenge_validation_sample: Dataset({
# ...

# %%
data = load_dataset("gem", "schema_guided_dialog")
data
# Out:
# ...
# Dataset gem downloaded and prepared to /root/.cache/huggingface/datasets/gem/schema_guided_dialog/1.1.0/a94b3f239aacc2081ffa3ea4414c3cddff25bb680c09756a27ec3e76547187b4. Subsequent calls will reuse this data.
# DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'dialog_acts', 'context', 'dialog_id', 'service', 'turn_id', 'prompt', 'target', 'references'],
#         num_rows: 164982
#     })
#     validation: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'dialog_acts', 'context', 'dialog_id', 'service', 'turn_id', 'prompt', 'target', 'references'],
#         num_rows: 10000
#     })
#     test: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'dialog_acts', 'context', 'dialog_id', 'service', 'turn_id', 'prompt', 'target', 'references'],
#         num_rows: 10000
#     })
#     challenge_train_sample: Dataset({
# ...

# %%
data = load_dataset("gem", "totto")
data
# Out:
# ...
# Dataset gem downloaded and prepared to /root/.cache/huggingface/datasets/gem/totto/1.1.0/a94b3f239aacc2081ffa3ea4414c3cddff25bb680c09756a27ec3e76547187b4. Subsequent calls will reuse this data.
# DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'totto_id', 'table_page_title', 'table_webpage_url', 'table_section_title', 'table_section_text', 'table', 'highlighted_cells', 'example_id', 'sentence_annotations', 'overlap_subset', 'target', 'references'],
#         num_rows: 121153
#     })
#     validation: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'totto_id', 'table_page_title', 'table_webpage_url', 'table_section_title', 'table_section_text', 'table', 'highlighted_cells', 'example_id', 'sentence_annotations', 'overlap_subset', 'target', 'references'],
#         num_rows: 7700
#     })
#     test: Dataset({
# ...

# %%
data = load_dataset("gem", "dart")
data
# Out:
# ...
# Dataset gem downloaded and prepared to /root/.cache/huggingface/datasets/gem/dart/1.1.0/a94b3f239aacc2081ffa3ea4414c3cddff25bb680c09756a27ec3e76547187b4. Subsequent calls will reuse this data.
# DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'dart_id', 'tripleset', 'subtree_was_extended', 'target_sources', 'target', 'references'],
#         num_rows: 62659
#     })
#     validation: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'dart_id', 'tripleset', 'subtree_was_extended', 'target_sources', 'target', 'references'],
#         num_rows: 2768
#     })
#     test: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'dart_id', 'tripleset', 'subtree_was_extended', 'target_sources', 'target', 'references'],
#         num_rows: 5097
#     })
# })

# %%
data = load_dataset("gem", "xsum")
data
# Out:
# ...
# Dataset gem downloaded and prepared to /root/.cache/huggingface/datasets/gem/xsum/1.1.0/a94b3f239aacc2081ffa3ea4414c3cddff25bb680c09756a27ec3e76547187b4. Subsequent calls will reuse this data.
# DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'xsum_id', 'document', 'target', 'references'],
#         num_rows: 23206
#     })
#     validation: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'xsum_id', 'document', 'target', 'references'],
#         num_rows: 1117
#     })
#     test: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'xsum_id', 'document', 'target', 'references'],
#         num_rows: 1166
#     })
#     challenge_train_sample: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'xsum_id', 'document', 'target', 'references'],
#         num_rows: 500
#     })
#     challenge_validation_sample: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'xsum_id', 'document', 'target', 'references'],
# ...

# %%
data = load_dataset("gem", "mlsum_de")
data
# Out:
# Reusing dataset gem (/root/.cache/huggingface/datasets/gem/mlsum_de/1.1.0/a94b3f239aacc2081ffa3ea4414c3cddff25bb680c09756a27ec3e76547187b4)
# DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'text', 'topic', 'url', 'title', 'date', 'target', 'references'],
#         num_rows: 220748
#     })
#     validation: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'text', 'topic', 'url', 'title', 'date', 'target', 'references'],
#         num_rows: 11392
#     })
#     test: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'text', 'topic', 'url', 'title', 'date', 'target', 'references'],
#         num_rows: 10695
#     })
#     challenge_train_sample: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'text', 'topic', 'url', 'title', 'date', 'target', 'references'],
#         num_rows: 500
#     })
#     challenge_validation_sample: Dataset({
# ...

# %%
datasets = ['mlsum_de', 'mlsum_es', 'wiki_lingua_es_en_v0', 'wiki_lingua_ru_en_v0', 'wiki_lingua_tr_en_v0', 'wiki_lingua_vi_en_v0', 'wiki_lingua_arabic_ar', 'wiki_lingua_chinese_zh', 'wiki_lingua_czech_cs', 'wiki_lingua_dutch_nl', 'wiki_lingua_english_en', 'wiki_lingua_french_fr', 'wiki_lingua_german_de', 'wiki_lingua_hindi_hi', 'wiki_lingua_indonesian_id', 'wiki_lingua_italian_it', 'wiki_lingua_japanese_ja', 'wiki_lingua_korean_ko', 'wiki_lingua_portuguese_pt', 'wiki_lingua_russian_ru', 'wiki_lingua_spanish_es', 'wiki_lingua_thai_th', 'wiki_lingua_turkish_tr', 'wiki_lingua_vietnamese_vi', 'xsum', 'common_gen', 'cs_restaurants', 'dart', 'e2e_nlg', 'totto', 'web_nlg_en', 'web_nlg_ru', 'wiki_auto_asset_turk', 'schema_guided_dialog']

for dataset in datasets:
  data = load_dataset("gem", "mlsum_de")
  print(dataset, data)
# Out:
# Reusing dataset gem (/root/.cache/huggingface/datasets/gem/mlsum_de/1.1.0/a94b3f239aacc2081ffa3ea4414c3cddff25bb680c09756a27ec3e76547187b4)
# mlsum_de DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'text', 'topic', 'url', 'title', 'date', 'target', 'references'],
#         num_rows: 220748
#     })
#     validation: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'text', 'topic', 'url', 'title', 'date', 'target', 'references'],
#         num_rows: 11392
#     })
#     test: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'text', 'topic', 'url', 'title', 'date', 'target', 'references'],
#         num_rows: 10695
#     })
#     challenge_train_sample: Dataset({
#         features: ['gem_id', 'gem_parent_id', 'text', 'topic', 'url', 'title', 'date', 'target', 'references'],
#         num_rows: 500
#     })
#     challenge_validation_sample: Dataset({
# ...
